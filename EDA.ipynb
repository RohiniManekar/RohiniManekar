# %% [markdown]
# <a href="https://colab.research.google.com/github/RohiniManekar/RohiniManekar/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exploratory Data Analysis of (Latest covid-19 India status) Data set.
# By Rohini Manekar<br>Start date : 03-08-2021<br>
# End date : 10-08-2021

# %%
# !pip install numpy 
# !pip install pandas

# %%
# importing all the useful libraries 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data=pd.read_csv("/content/Latest Covid-19 India Status.csv")
print(data.shape) # printing shape of data set 
data.head()       # printing top 5 rows
# Out:
# (36, 8)
#              State/UTs  Total Cases  ...  Discharge Ratio (%)  Death Ratio (%)
# 0  Andaman and Nicobar         7525  ...                98.10             1.71
# 1       Andhra Pradesh      1952513  ...                98.18             0.68
# 2    Arunachal Pradesh        45703  ...                89.76             0.47
# 3                Assam       557437  ...                96.26             0.92
# 4                Bihar       724390  ...                98.60             1.33
#
# [5 rows x 8 columns]

# %%
data.tail() #printing last 5 rows
# Out:
#         State/UTs  Total Cases  ...  Discharge Ratio (%)  Death Ratio (%)
# 31      Telengana       640659  ...                97.91             0.59
# 32        Tripura        76315  ...                93.88             0.97
# 33  Uttar Pradesh      1708152  ...                98.61             1.33
# 34    Uttarakhand       341673  ...                97.67             2.15
# 35    West Bengal      1522833  ...                98.03             1.19
#
# [5 rows x 8 columns]

# %%
data.info() # basic info about data set (data type of columns and count of non null values )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
data.isnull().sum()  #no null values found
# Out:
# State/UTs              0
# Total Cases            0
# Active                 0
# Discharged             0
# Deaths                 0
# Active Ratio (%)       0
# Discharge Ratio (%)    0
# Death Ratio (%)        0
# dtype: int64

# %%
data.describe()
# Out:
#         Total Cases        Active  ...  Discharge Ratio (%)  Death Ratio (%)
# count  3.600000e+01  3.600000e+01  ...            36.000000        36.000000
# mean   8.714417e+05  4.599578e+04  ...            96.074722         1.260000
# std    1.255645e+06  2.303794e+05  ...             4.877221         0.565241
# min    7.525000e+03  1.400000e+01  ...            74.610000         0.040000
# 25%    6.159075e+04  4.830000e+02  ...            96.327500         0.935000
# 50%    4.521775e+05  1.275000e+03  ...            97.915000         1.330000
# 75%    9.745455e+05  9.781500e+03  ...            98.602500         1.617500
# max    6.258079e+06  1.386262e+06  ...            99.510000         2.720000
#
# [8 rows x 7 columns]

# %%
data['State/UTs'].value_counts()
# Out:
# Bihar                                       1
# Odisha                                      1
# Madhya Pradesh                              1
# Andaman and Nicobar                         1
# Sikkim                                      1
# West Bengal                                 1
# Rajasthan                                   1
# Meghalaya                                   1
# Tripura                                     1
# Kerala                                      1
# Chhattisgarh                                1
# Uttarakhand                                 1
# Mizoram                                     1
# Uttar Pradesh                               1
# Haryana                                     1
# Karnataka                                   1
# Lakshadweep                                 1
# Andhra Pradesh                              1
# Ladakh                                      1
# Nagaland                                    1
# ...

# %%
data.replace('Dadra and Nagar Haveli and Daman and Diu','Daman and Diu', inplace=True) #shorting the name

# %%
data['Total Cases'].describe()
# Out:
# count    3.600000e+01
# mean     8.714417e+05
# std      1.255645e+06
# min      7.525000e+03
# 25%      6.159075e+04
# 50%      4.521775e+05
# 75%      9.745455e+05
# max      6.258079e+06
# Name: Total Cases, dtype: float64

# %%
data_copy = data.copy()

# %%
data_mean=df_copy['Total Cases'].mean()
data_std=df_copy['Total Cases'].std()

# %%
data_copy['Total Cases']=(data_copy['Total Cases'] - data_mean)/data_std  #converting to normal dis

# %%
def normalize(column):
  data_mean = column.mean()
  data_std = column.std()

  return (column - data_mean)/data_std

# %%
features=['Active',	'Discharged','Deaths',	'Active Ratio (%)',		'Death Ratio (%)']
for feature in features :
  data_copy[feature]=normalize(data_copy[feature])

# %%
data_copy.head()      # preprocessing done
# Out:
#              State/UTs  Total Cases  ...  Discharge Ratio (%)  Death Ratio (%)
# 0  Andaman and Nicobar    -0.688026  ...                98.10         0.796121
# 1       Andhra Pradesh     0.860969  ...                98.18        -1.026111
# 2    Arunachal Pradesh    -0.657621  ...                89.76        -1.397634
# 3                Assam    -0.250074  ...                96.26        -0.601514
# 4                Bihar    -0.117112  ...                98.60         0.123841
#
# [5 rows x 8 columns]

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation=320)
plt.bar(data["State/UTs"],data["Active Ratio (%)"])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data.head()
# Out:
#              State/UTs  Total Cases  ...  Discharge Ratio (%)  Death Ratio (%)
# 0  Andaman and Nicobar         7525  ...                98.10             1.71
# 1       Andhra Pradesh      1952513  ...                98.18             0.68
# 2    Arunachal Pradesh        45703  ...                89.76             0.47
# 3                Assam       557437  ...                96.26             0.92
# 4                Bihar       724390  ...                98.60             1.33
#
# [5 rows x 8 columns]

# %%
plt.figure(figsize=(25,15))

plt.subplot(2,2,1)
plt.plot(data['State/UTs'], data['Total Cases'], '-b', label='Total Cases')
plt.plot(data['State/UTs'], data['Active'], '-r', label='Active Cases')
plt.xticks(rotation=270)
plt.title('Total cases')
plt.xlabel('States/UTs')
plt.ylabel('Total Cases')
plt.legend()

plt.subplot(2,2,2)
plt.plot(data['State/UTs'], data['Active'], label='Active Cases')
plt.xticks(rotation=270)
plt.title('Active cases')
plt.xlabel('States/UTs')
plt.ylabel('Active')
plt.legend()

plt.subplot(2,2,3)
plt.plot(data['State/UTs'], data['Discharged'], label='Discharged Cases')
plt.xticks(rotation=270)
plt.title('Discharged cases')
plt.xlabel('States/UTs')
plt.ylabel('Discharged')
plt.legend()

plt.subplot(2,2,4)
plt.plot(data['State/UTs'], data['Deaths'], label='Deaths')
plt.xticks(rotation=270)
plt.title('Deaths')
plt.xlabel('States/UTs')
plt.ylabel('Deaths')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation=270)
sb.barplot(data['Total Cases'], data['State/UTs'], orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sb.heatmap(data.corr()) # Extend of relation between various columns

# %%
sb.pairplot(data)
